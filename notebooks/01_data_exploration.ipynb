# %% [markdown]
# # 01 — Data Exploration

# %% [markdown]
# Load the sample dataset and inspect distributions, missingness, and basic correlations.

# %%
import pandas as pd
df = pd.read_csv('../data/sample_data.csv')
df.head()

# %%
df.describe()

# %%
df.corr(numeric_only=True)
