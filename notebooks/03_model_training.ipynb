# %% [markdown]
# # 03 — Model Training

# %% [markdown]
# Train Linear Regression, KNN, and Random Forest on the sample data.

# %%
import sys; sys.path.append('..')
from src.models import run
run('../config/config.yaml')
