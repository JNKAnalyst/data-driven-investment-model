# %% [markdown]
# # 02 — Feature Engineering

# %% [markdown]
# Apply the project's feature pipeline and inspect the resulting feature matrix.

# %%
import pandas as pd
import sys; sys.path.append('..')
from src.features import engineer_features, add_rolling_features

df = pd.read_csv('../data/sample_data.csv')
X = engineer_features(df)
X = add_rolling_features(X, columns=['sp500_return', 'vix'], windows=[3, 7])
X.head()
